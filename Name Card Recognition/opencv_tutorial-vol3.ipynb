# %% [markdown]
# # OpenCV를 이용한 명함인식 구현 Tutorial - vol3
# [Tutorial - vol02](https://github.com/ExcelsiorCJH/Projects/blob/master/Name%20Card%20Recognition/tutorial-vol2.ipynb)를 확장하여 노트북의 웹캠을 이용하여 실시간 명함인식기 구현 튜토리얼

# %%
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 웹캠을 이용해 Edge Detection 해보기

# %%
try: 
    cap = cv2.VideoCapture(0)
except:
    print ('cannot load camera!')

while True:
    ret, frame = cap.read()
    if not ret:
        print ('cannot load camera!')
        break

    k = cv2.waitKey(10)
    if k == 27:
        break

    # convert the image to grayscale, blur it, and find edges
    # in the image
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (3, 3), 0)
    edged = cv2.Canny(gray, 75, 200)

    # show the original image and the edge detected image
    print ("STEP 1: Edge Detection")

    # find the contours in the edged image, keeping only the
    # largest ones, and initialize the screen contour
    (_, cnts, _) = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    cnts = sorted(cnts, key = cv2.contourArea, reverse = True)[:5]

    # loop over the contours
    for c in cnts:
        # approximate the contour
        peri = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, 0.02 * peri, True)
        screenCnt = []

        # if our approximated contour has four points, then we
        # can assume that we have found our screen
        if len(approx) == 4:
            contourSize = cv2.contourArea(approx)
            camSize = frame.shape[0] * frame.shape[1]
            ratio = contourSize / camSize
            print (contourSize)
            print (camSize)
            print (ratio)

            if ratio > 0.1:
                screenCnt = approx

            break 

    if len(screenCnt) == 0:
        cv2.imshow("WebCam", frame)
        continue

    else:
        # show the contour (outline) of the piece of paper
        print ("STEP 2: Find contours of paper")

        cv2.drawContours(frame, [screenCnt], -1, (0, 255, 0), 2)
        cv2.imshow("WebCam", frame)


cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# STEP 1: Edge Detection
# 651.0
# 921600
# 0.0007063802083333334
# STEP 1: Edge Detection
# 524.5
# 921600
# 0.0005691189236111111
# STEP 1: Edge Detection
# 292.5
# 921600
# 0.0003173828125
# STEP 1: Edge Detection
# 116.0
# 921600
# 0.00012586805555555555
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 98.5
# 921600
# 0.00010687934027777777
# STEP 1: Edge Detection
# 292.5
# 921600
# 0.0003173828125
# STEP 1: Edge Detection
# 1443.0
# 921600
# 0.0015657552083333333
# STEP 1: Edge Detection
# 85.5
# 921600
# 9.27734375e-05
# STEP 1: Edge Detection
# 84.0
# 921600
# 9.114583333333334e-05
# STEP 1: Edge Detection
# 324.0
# 921600
# 0.0003515625
# STEP 1: Edge Detection
# 33.5
# 921600
# 3.6349826388888886e-05
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 274.0
# 921600
# 0.0002973090277777778
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 274.0
# 921600
# 0.0002973090277777778
# STEP 1: Edge Detection
# 368.0
# 921600
# 0.0003993055555555556
# STEP 1: Edge Detection
# 500.5
# 921600
# 0.0005430772569444444
# STEP 1: Edge Detection
# 440.0
# 921600
# 0.00047743055555555554
# STEP 1: Edge Detection
# 467.0
# 921600
# 0.0005067274305555555
# STEP 1: Edge Detection
# 509.0
# 921600
# 0.0005523003472222223
# STEP 1: Edge Detection
# 560.0
# 921600
# 0.0006076388888888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 614.0
# 921600
# 0.0006662326388888888
# STEP 1: Edge Detection
# 638.0
# 921600
# 0.0006922743055555556
# STEP 1: Edge Detection
# 106.0
# 921600
# 0.0001150173611111111
# STEP 1: Edge Detection
# 0.0
# 921600
# 0.0
# STEP 1: Edge Detection
# 86.0
# 921600
# 9.331597222222223e-05
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 270.0
# 921600
# 0.00029296875
# STEP 1: Edge Detection
# 290.0
# 921600
# 0.0003146701388888889
# STEP 1: Edge Detection
# 6780.0
# 921600
# 0.007356770833333333
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 322.0
# 921600
# 0.0003493923611111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 655.0
# 921600
# 0.0007107204861111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 274.0
# 921600
# 0.0002973090277777778
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 292.5
# 921600
# 0.0003173828125
# STEP 1: Edge Detection
# 322.0
# 921600
# 0.0003493923611111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 270.0
# 921600
# 0.00029296875
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 653.0
# 921600
# 0.0007085503472222222
# STEP 1: Edge Detection
# 578.0
# 921600
# 0.0006271701388888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 426.0
# 921600
# 0.00046223958333333333
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 44080.0
# 921600
# 0.04782986111111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 841.5
# 921600
# 0.0009130859375
# STEP 1: Edge Detection
# 70470.0
# 921600
# 0.07646484375
# STEP 1: Edge Detection
# 76213.5
# 921600
# 0.08269694010416667
# STEP 1: Edge Detection
# 78051.5
# 921600
# 0.08469129774305556
# STEP 1: Edge Detection
# 80449.5
# 921600
# 0.08729329427083334
# STEP 1: Edge Detection
# 79816.5
# 921600
# 0.0866064453125
# STEP 1: Edge Detection
# 78911.0
# 921600
# 0.08562391493055556
# STEP 1: Edge Detection
# 77775.0
# 921600
# 0.08439127604166667
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 307.5
# 921600
# 0.0003336588541666667
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 72692.5
# 921600
# 0.07887641059027778
# STEP 1: Edge Detection
# 72836.0
# 921600
# 0.07903211805555556
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 77354.0
# 921600
# 0.08393446180555555
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 85584.5
# 921600
# 0.09286512586805555
# STEP 1: Edge Detection
# 89115.0
# 921600
# 0.09669596354166667
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 97110.5
# 921600
# 0.10537163628472222
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 86.0
# 921600
# 9.331597222222223e-05
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 6993.0
# 921600
# 0.007587890625
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 817.0
# 921600
# 0.0008865017361111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 10000.5
# 921600
# 0.010851236979166666
# STEP 1: Edge Detection
# 55.0
# 921600
# 5.967881944444444e-05
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 123330.5
# 921600
# 0.13382215711805556
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 362.0
# 921600
# 0.00039279513888888887
# STEP 1: Edge Detection
# 380.0
# 921600
# 0.0004123263888888889
# STEP 1: Edge Detection
# 401.5
# 921600
# 0.00043565538194444446
# STEP 1: Edge Detection
# 428.0
# 921600
# 0.00046440972222222223
# STEP 1: Edge Detection
# 129593.5
# 921600
# 0.1406179470486111
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 130868.0
# 921600
# 0.14200086805555556
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 131836.0
# 921600
# 0.14305121527777778
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 133325.0
# 921600
# 0.14466688368055555
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 133067.5
# 921600
# 0.14438747829861112
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 131857.0
# 921600
# 0.14307400173611112
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 132398.5
# 921600
# 0.14366156684027778
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 132911.5
# 921600
# 0.14421820746527778
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 133163.0
# 921600
# 0.14449110243055555
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 132100.0
# 921600
# 0.1433376736111111
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 130986.0
# 921600
# 0.14212890625
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 375.0
# 921600
# 0.0004069010416666667
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 1602.0
# 921600
# 0.00173828125
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 77.0
# 921600
# 8.355034722222222e-05
# STEP 1: Edge Detection
# 5246.5
# 921600
# 0.005692816840277778
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 284.5
# 921600
# 0.00030870225694444445
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 250.0
# 921600
# 0.0002712673611111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 324.0
# 921600
# 0.0003515625
# STEP 1: Edge Detection
# 353.0
# 921600
# 0.0003830295138888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 26.0
# 921600
# 2.8211805555555554e-05
# STEP 1: Edge Detection
# 232.0
# 921600
# 0.0002517361111111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 97.5
# 921600
# 0.00010579427083333334
# STEP 1: Edge Detection
# 829.0
# 921600
# 0.0008995225694444444
# STEP 1: Edge Detection
# 106.0
# 921600
# 0.0001150173611111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 112.5
# 921600
# 0.0001220703125
# STEP 1: Edge Detection
# 30.5
# 921600
# 3.309461805555556e-05
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 108.0
# 921600
# 0.0001171875
# STEP 1: Edge Detection
# 611.5
# 921600
# 0.0006635199652777777
# STEP 1: Edge Detection
# 598.5
# 921600
# 0.0006494140625
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 1724.5
# 921600
# 0.0018712022569444444
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 66.0
# 921600
# 7.161458333333333e-05
# STEP 1: Edge Detection
# 61.0
# 921600
# 6.618923611111112e-05
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 287.0
# 921600
# 0.00031141493055555556
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 562.5
# 921600
# 0.0006103515625
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 990.0
# 921600
# 0.00107421875
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 184.5
# 921600
# 0.0002001953125
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 168.0
# 921600
# 0.00018229166666666667
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 197.5
# 921600
# 0.00021430121527777778
# STEP 1: Edge Detection
# 280.0
# 921600
# 0.00030381944444444445
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 270.0
# 921600
# 0.00029296875
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 344.0
# 921600
# 0.0003732638888888889
# STEP 1: Edge Detection
# 426.0
# 921600
# 0.00046223958333333333
# STEP 1: Edge Detection
# 384.0
# 921600
# 0.0004166666666666667
# STEP 1: Edge Detection
# 461.0
# 921600
# 0.0005002170138888889
# STEP 1: Edge Detection
# 386.0
# 921600
# 0.00041883680555555554
# STEP 1: Edge Detection
# 464.0
# 921600
# 0.0005034722222222222
# STEP 1: Edge Detection
# 388.0
# 921600
# 0.00042100694444444444
# STEP 1: Edge Detection
# 1634.0
# 921600
# 0.0017730034722222223
# STEP 1: Edge Detection
# 410.0
# 921600
# 0.0004448784722222222
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 67.5
# 921600
# 7.32421875e-05
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 531.0
# 921600
# 0.000576171875
# STEP 1: Edge Detection
# 554.0
# 921600
# 0.0006011284722222222
# STEP 1: Edge Detection
# 578.0
# 921600
# 0.0006271701388888889
# STEP 1: Edge Detection
# 591.0
# 921600
# 0.0006412760416666666
# STEP 1: Edge Detection
# 666.0
# 921600
# 0.00072265625
# STEP 1: Edge Detection
# 546.0
# 921600
# 0.0005924479166666667
# STEP 1: Edge Detection
# 93.0
# 921600
# 0.00010091145833333333
# STEP 1: Edge Detection
# 572.0
# 921600
# 0.0006206597222222222
# STEP 1: Edge Detection
# 452.0
# 921600
# 0.0004904513888888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 452.0
# 921600
# 0.0004904513888888889
# STEP 1: Edge Detection
# 452.0
# 921600
# 0.0004904513888888889
# STEP 1: Edge Detection
# 93.0
# 921600
# 0.00010091145833333333
# STEP 1: Edge Detection
# 452.0
# 921600
# 0.0004904513888888889
# STEP 1: Edge Detection
# 995.0
# 921600
# 0.0010796440972222223
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 272.0
# 921600
# 0.0002951388888888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 452.0
# 921600
# 0.0004904513888888889
# STEP 1: Edge Detection
# 420.0
# 921600
# 0.0004557291666666667
# STEP 1: Edge Detection
# 0.0
# 921600
# 0.0
# STEP 1: Edge Detection
# 2512.0
# 921600
# 0.0027256944444444446
# STEP 1: Edge Detection
# 296.0
# 921600
# 0.00032118055555555556
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 39.0
# 921600
# 4.2317708333333335e-05
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 274.0
# 921600
# 0.0002973090277777778
# STEP 1: Edge Detection
# 0.0
# 921600
# 0.0
# STEP 1: Edge Detection
# 0.0
# 921600
# 0.0
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 458.0
# 921600
# 0.0004969618055555555
# STEP 1: Edge Detection
# 114.0
# 921600
# 0.00012369791666666668
# STEP 1: Edge Detection
# 290.0
# 921600
# 0.0003146701388888889
# STEP 1: Edge Detection
# 414.0
# 921600
# 0.00044921875
# STEP 1: Edge Detection
# 414.0
# 921600
# 0.00044921875
# STEP 1: Edge Detection
# 224.0
# 921600
# 0.00024305555555555555
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 430.0
# 921600
# 0.00046657986111111113
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 20.5
# 921600
# 2.2243923611111112e-05
# STEP 1: Edge Detection
# 0.0
# 921600
# 0.0
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 274.0
# 921600
# 0.0002973090277777778
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 0.0
# 921600
# 0.0
# STEP 1: Edge Detection
# 272.0
# 921600
# 0.0002951388888888889
# STEP 1: Edge Detection
# 272.0
# 921600
# 0.0002951388888888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 418.0
# 921600
# 0.00045355902777777777
# STEP 1: Edge Detection
# 418.0
# 921600
# 0.00045355902777777777
# STEP 1: Edge Detection
# 416.0
# 921600
# 0.00045138888888888887
# STEP 1: Edge Detection
# 509.0
# 921600
# 0.0005523003472222223
# STEP 1: Edge Detection
# 509.0
# 921600
# 0.0005523003472222223
# STEP 1: Edge Detection
# 493.0
# 921600
# 0.0005349392361111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 550.0
# 921600
# 0.0005967881944444445
# STEP 1: Edge Detection
# 506.0
# 921600
# 0.0005490451388888888
# STEP 1: Edge Detection
# 506.0
# 921600
# 0.0005490451388888888
# STEP 1: Edge Detection
# 503.0
# 921600
# 0.0005457899305555555
# STEP 1: Edge Detection
# 506.0
# 921600
# 0.0005490451388888888
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 418.0
# 921600
# 0.00045355902777777777
# STEP 1: Edge Detection
# 274.0
# 921600
# 0.0002973090277777778
# STEP 1: Edge Detection
# 422.0
# 921600
# 0.0004578993055555556
# STEP 1: Edge Detection
# 521.0
# 921600
# 0.0005653211805555556
# STEP 1: Edge Detection
# 527.0
# 921600
# 0.0005718315972222223
# STEP 1: Edge Detection
# 430.0
# 921600
# 0.00046657986111111113
# STEP 1: Edge Detection
# 432.0
# 921600
# 0.00046875
# STEP 1: Edge Detection
# 432.0
# 921600
# 0.00046875
# STEP 1: Edge Detection
# 432.0
# 921600
# 0.00046875
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 525.0
# 921600
# 0.0005696614583333334
# STEP 1: Edge Detection
# 527.0
# 921600
# 0.0005718315972222223
# STEP 1: Edge Detection
# 538.0
# 921600
# 0.0005837673611111111
# STEP 1: Edge Detection
# 551.0
# 921600
# 0.0005978732638888889
# STEP 1: Edge Detection
# 562.0
# 921600
# 0.0006098090277777778
# STEP 1: Edge Detection
# 568.0
# 921600
# 0.0006163194444444444
# STEP 1: Edge Detection
# 573.0
# 921600
# 0.0006217447916666667
# STEP 1: Edge Detection
# 102.5
# 921600
# 0.00011121961805555555
# STEP 1: Edge Detection
# 0.0
# 921600
# 0.0
# STEP 1: Edge Detection
# 582.0
# 921600
# 0.0006315104166666666
# STEP 1: Edge Detection
# 579.0
# 921600
# 0.0006282552083333333
# STEP 1: Edge Detection
# 572.0
# 921600
# 0.0006206597222222222
# STEP 1: Edge Detection
# 572.0
# 921600
# 0.0006206597222222222
# STEP 1: Edge Detection
# 274.0
# 921600
# 0.0002973090277777778
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 544.0
# 921600
# 0.0005902777777777778
# STEP 1: Edge Detection
# 548.0
# 921600
# 0.0005946180555555556
# STEP 1: Edge Detection
# 539.0
# 921600
# 0.0005848524305555556
# STEP 1: Edge Detection
# 527.0
# 921600
# 0.0005718315972222223
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 322.0
# 921600
# 0.0003493923611111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 372.0
# 921600
# 0.00040364583333333333
# STEP 1: Edge Detection
# 421.0
# 921600
# 0.0004568142361111111
# STEP 1: Edge Detection
# 412.0
# 921600
# 0.0004470486111111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 0.0
# 921600
# 0.0
# STEP 1: Edge Detection
# 0.0
# 921600
# 0.0
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
#
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 155957.5
# 921600
# 0.16922471788194443
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 156227.5
# 921600
# 0.16951768663194444
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 156163.0
# 921600
# 0.16944769965277778
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 156649.5
# 921600
# 0.1699755859375
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 156055.0
# 921600
# 0.16933051215277778
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 154960.0
# 921600
# 0.1681423611111111
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 155202.0
# 921600
# 0.16840494791666666
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 154622.5
# 921600
# 0.1677761501736111
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 154622.5
# 921600
# 0.1677761501736111
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 153759.0
# 921600
# 0.16683919270833333
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 153664.0
# 921600
# 0.1667361111111111
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 154680.0
# 921600
# 0.16783854166666667
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# 154704.5
# 921600
# 0.16786512586805555
# STEP 2: Find contours of paper
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 390.0
# 921600
# 0.00042317708333333335
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 364.0
# 921600
# 0.0003949652777777778
# STEP 1: Edge Detection
# 428.0
# 921600
# 0.00046440972222222223
# STEP 1: Edge Detection
# 443.0
# 921600
# 0.0004806857638888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 455.0
# 921600
# 0.0004937065972222222
# STEP 1: Edge Detection
# 430.0
# 921600
# 0.00046657986111111113
# STEP 1: Edge Detection
# 473.0
# 921600
# 0.0005132378472222222
# STEP 1: Edge Detection
# 535.0
# 921600
# 0.0005805121527777778
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 500.0
# 921600
# 0.0005425347222222222
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 185.5
# 921600
# 0.00020128038194444444
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 399.0
# 921600
# 0.00043294270833333336
# STEP 1: Edge Detection
# 274.0
# 921600
# 0.0002973090277777778
# STEP 1: Edge Detection
# 274.0
# 921600
# 0.0002973090277777778
# STEP 1: Edge Detection
# 290.0
# 921600
# 0.0003146701388888889
# STEP 1: Edge Detection
# 274.0
# 921600
# 0.0002973090277777778
# STEP 1: Edge Detection
# 254.0
# 921600
# 0.0002756076388888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 272.0
# 921600
# 0.0002951388888888889
# STEP 1: Edge Detection
# 272.0
# 921600
# 0.0002951388888888889
# STEP 1: Edge Detection
# 618.0
# 921600
# 0.0006705729166666666
# STEP 1: Edge Detection
# 237.0
# 921600
# 0.0002571614583333333
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 437.0
# 921600
# 0.00047417534722222224
# STEP 1: Edge Detection
# 137.0
# 921600
# 0.0001486545138888889
# STEP 1: Edge Detection
# 135.5
# 921600
# 0.00014702690972222222
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 326.0
# 921600
# 0.0003537326388888889
# STEP 1: Edge Detection
# 29.0
# 921600
# 3.146701388888889e-05
# STEP 1: Edge Detection
# 322.0
# 921600
# 0.0003493923611111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 762.0
# 921600
# 0.0008268229166666667
# STEP 1: Edge Detection
# 710.0
# 921600
# 0.0007703993055555555
# STEP 1: Edge Detection
# 855.0
# 921600
# 0.000927734375
# STEP 1: Edge Detection
# 272.0
# 921600
# 0.0002951388888888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 1516.5
# 921600
# 0.0016455078125
# STEP 1: Edge Detection
# 324.0
# 921600
# 0.0003515625
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 25816.0
# 921600
# 0.028012152777777778
# STEP 1: Edge Detection
# 336.0
# 921600
# 0.00036458333333333335
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 7126.5
# 921600
# 0.007732747395833333
# STEP 1: Edge Detection
# 324.0
# 921600
# 0.0003515625
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 814.0
# 921600
# 0.0008832465277777778
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 340.0
# 921600
# 0.0003689236111111111
# STEP 1: Edge Detection
# 242.5
# 921600
# 0.00026312934027777776
# STEP 1: Edge Detection
# 307.0
# 921600
# 0.0003331163194444444
# STEP 1: Edge Detection
# 322.5
# 921600
# 0.00034993489583333334
# STEP 1: Edge Detection
# 342.5
# 921600
# 0.0003716362847222222
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 292.5
# 921600
# 0.0003173828125
# STEP 1: Edge Detection
# 320.5
# 921600
# 0.00034776475694444443
# STEP 1: Edge Detection
# 320.5
# 921600
# 0.00034776475694444443
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 717.5
# 921600
# 0.0007785373263888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 715.0
# 921600
# 0.0007758246527777777
# STEP 1: Edge Detection
# 324.0
# 921600
# 0.0003515625
# STEP 1: Edge Detection
# 1952.5
# 921600
# 0.0021185980902777776
# STEP 1: Edge Detection
# -1

# %% [markdown]
# ## 2. Perspective Transform 에서 부터 Threshold 처리까지

# %%
def order_points(pts):
    # initialzie a list of coordinates that will be ordered
    # such that the first entry in the list is the top-left,
    # the second entry is the top-right, the third is the
    # bottom-right, and the fourth is the bottom-left
    rect = np.zeros((4, 2), dtype = "float32")

    # the top-left point will have the smallest sum, whereas
    # the bottom-right point will have the largest sum
    s = pts.sum(axis = 1)
    rect[0] = pts[np.argmin(s)]
    rect[2] = pts[np.argmax(s)]

    # now, compute the difference between the points, the
    # top-right point will have the smallest difference,
    # whereas the bottom-left will have the largest difference
    diff = np.diff(pts, axis = 1)
    rect[1] = pts[np.argmin(diff)]
    rect[3] = pts[np.argmax(diff)]

    # return the ordered coordinates
    return rect

try:
    cap = cv2.VideoCapture(0)
except:
    print('cannot load camera!')

while True:
    ret, frame = cap.read()
    if not ret:
        print('cannot load camera!')
        break
    
    k = cv2.waitKey(10) & 0xff
    if k == 27:
        break
        
    # convert the image to grayscale, blur it, and find edges
    # in the image
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (3, 3), 0)
    edged = cv2.Canny(gray, 75, 200)

    # show the original image and the edge detected image
    print ("STEP 1: Edge Detection")

    # find the contours in the edged image, keeping only the
    # largest ones, and initialize the screen contour
    (_, cnts, _) = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    cnts = sorted(cnts, key = cv2.contourArea, reverse = True)[:5]

    # loop over the contours
    for c in cnts:
        # approximate the contour
        peri = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, 0.02 * peri, True)
        screenCnt = []

        # if our approximated contour has four points, then we
        # can assume that we have found our screen
        if len(approx) == 4:
            contourSize = cv2.contourArea(approx)
            camSize = frame.shape[0] * frame.shape[1]
            ratio = contourSize / camSize
            print (contourSize)
            print (camSize)
            print (ratio)

            if ratio > 0.1:
                screenCnt = approx

            break 

    if len(screenCnt) == 0:
        cv2.imshow("WebCam", frame)
        continue

    else:
        # show the contour (outline) of the piece of paper
        print ("STEP 2: Find contours of paper")

        cv2.drawContours(frame, [screenCnt], -1, (0, 255, 0), 2)
        cv2.imshow("WebCam", frame)
        
        # apply the four point transform to obtain a top-down
        # view of the original image
        rect = order_points(screenCnt.reshape(4, 2))
        (topLeft, topRight, bottomRight, bottomLeft) = rect

        w1 = abs(bottomRight[0] - bottomLeft[0])
        w2 = abs(topRight[0] - topLeft[0])
        h1 = abs(topRight[1] - bottomRight[1])
        h2 = abs(topLeft[1] - bottomLeft[1])
        maxWidth = max([w1, w2])
        maxHeight = max([h1, h2])

        dst = np.float32([[0,0], [maxWidth-1,0], 
                          [maxWidth-1,maxHeight-1], [0,maxHeight-1]])

        M = cv2.getPerspectiveTransform(rect, dst)
        warped = cv2.warpPerspective(frame, M, (maxWidth, maxHeight))

        # show the original and scanned images
        print ("STEP 3: Apply perspective transform")

        # convert the warped image to grayscale, then threshold it
        # to give it that 'black and white' paper effect
        warped = cv2.cvtColor(warped, cv2.COLOR_BGR2GRAY)
        warped = cv2.adaptiveThreshold(warped, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 21, 10)

        # show the original and scanned images
        print ("STEP 4: Apply Adaptive Threshold")

        break


cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)

cv2.imshow("Scanned", warped)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 569.0
# 921600
# 0.0006174045138888889
# STEP 1: Edge Detection
# 109.5
# 921600
# 0.00011881510416666667
# STEP 1: Edge Detection
# 608.0
# 921600
# 0.0006597222222222222
# STEP 1: Edge Detection
# 620.0
# 921600
# 0.0006727430555555556
# STEP 1: Edge Detection
# 626.0
# 921600
# 0.0006792534722222223
# STEP 1: Edge Detection
# 626.0
# 921600
# 0.0006792534722222223
# STEP 1: Edge Detection
# 620.0
# 921600
# 0.0006727430555555556
# STEP 1: Edge Detection
# 624.0
# 921600
# 0.0006770833333333334
# STEP 1: Edge Detection
# 624.0
# 921600
# 0.0006770833333333334
# STEP 1: Edge Detection
# 622.5
# 921600
# 0.0006754557291666667
# STEP 1: Edge Detection
# 622.5
# 921600
# 0.0006754557291666667
# STEP 1: Edge Detection
# 622.5
# 921600
# 0.0006754557291666667
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 620.0
# 921600
# 0.0006727430555555556
# STEP 1: Edge Detection
# 618.0
# 921600
# 0.0006705729166666666
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 542.0
# 921600
# 0.0005881076388888889
# STEP 1: Edge Detection
# 517.5
# 921600
# 0.0005615234375
# STEP 1: Edge Detection
# 496.5
# 921600
# 0.0005387369791666666
# STEP 1: Edge Detection
# 465.0
# 921600
# 0.0005045572916666667
# STEP 1: Edge Detection
# 435.5
# 921600
# 0.00047254774305555554
# STEP 1: Edge Detection
# 419.5
# 921600
# 0.0004551866319444444
# STEP 1: Edge Detection
# 409.0
# 921600
# 0.00044379340277777776
# STEP 1: Edge Detection
# 402.0
# 921600
# 0.00043619791666666666
# STEP 1: Edge Detection
# 395.0
# 921600
# 0.00042860243055555555
# STEP 1: Edge Detection
# 413.0
# 921600
# 0.00044813368055555557
# STEP 1: Edge Detection
# 413.0
# 921600
# 0.00044813368055555557
# STEP 1: Edge Detection
# 384.5
# 921600
# 0.0004172092013888889
# STEP 1: Edge Detection
# 384.5
# 921600
# 0.0004172092013888889
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 428.0
# 921600
# 0.00046440972222222223
# STEP 1: Edge Detection
# 440.0
# 921600
# 0.00047743055555555554
# STEP 1: Edge Detection
# 423.0
# 921600
# 0.000458984375
# STEP 1: Edge Detection
# 433.5
# 921600
# 0.0004703776041666667
# STEP 1: Edge Detection
# 444.0
# 921600
# 0.00048177083333333335
# STEP 1: Edge Detection
# 473.0
# 921600
# 0.0005132378472222222
# STEP 1: Edge Detection
# 479.0
# 921600
# 0.0005197482638888889
# STEP 1: Edge Detection
# 461.5
# 921600
# 0.0005007595486111111
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 461.5
# 921600
# 0.0005007595486111111
# STEP 1: Edge Detection
# 461.5
# 921600
# 0.0005007595486111111
# STEP 1: Edge Detection
# 451.0
# 921600
# 0.0004893663194444444
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 320.5
# 921600
# 0.00034776475694444443
# STEP 1: Edge Detection
# STEP 1: Edge Detection
# 113764.0
# 921600
# 0.12344184027777778
# STEP 2: Find contours of paper
# STEP 3: Apply perspective transform
# STEP 4: Apply Adaptive Threshold
